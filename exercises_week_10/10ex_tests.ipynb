# %%
import numpy as np
from scipy.stats import norm
from math import sqrt, pi, erf
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from scipy.stats import poisson
from scipy import stats
from scipy import optimize
import pandas as pd   
from scipy.optimize import curve_fit

# %% [markdown]
# 1\. **Hurricanes per Year**
#
# The number of hurricanes in 2005 was 15. The historic average is 6.3. Is this number signficantly different?
# - Assume the number of hurricanes is random, i.e. follows the Poisson distribution.
# - Assume as statistically significant a probability that has a Z score of 3 or larger with respect a normal distribution.
#
# **Hint**: compute the probability that in a single year are observed 15 or more hurricances.

# %%
x0 = 15 #number of hurricanes in 2005
mu = 6.3
sigma_mu = 2.8

#create poission distribution with historical average 6.3.
n_rvs = poisson.rvs(mu,size=1000)

# determine the Z score
Z = abs(x0 - np.mean(n_rvs)) / sigma_mu
print("Z =", Z)
# Out:
# Z = 3.110714285714286

# %% [markdown]
# 2\. **Pairwise t-test**
#
# In an experiment, a group of 10 individuals agreed to participate in a study of blood pressure changes following exposure to halogen lighting. Resting systolic blood pressure was recorded for each individual. The participants were then exposed to 20 minutes in a room lit only by halogen lamps. A post-exposure systolic blood pressure reading was recorded for each individual. The results are presented in the following data set:
#
# ```python
# pre = np.array([120, 132, 120, 110, 115, 128, 120, 112, 110, 100])
# post = np.array([140, 156, 145, 130, 117, 148, 137, 119, 127, 135])
# ```
#
# Determine whether the change in blood pressures within our sample was statistically significant.
#
# **Hint:**
# in this case, the Student's $t$-test should be performed to compare the two datasets.
# Use the following test statistics:
#
# $$T = \frac{\bar{x}_1 - \bar{x}_2}{\sigma \sqrt{\frac{2}{n}}}$$
#
# and
#
# $$\sigma = \sqrt{\frac{\sigma_1^2 + \sigma_2^2}{2}}$$

# %%
pre = np.array([120, 132, 120, 110, 115, 128, 120, 112, 110, 100])
post = np.array([140, 156, 145, 130, 117, 148, 137, 119, 127, 135])
n = 10 #number of samples/number of participants

sigma1 = np.var(pre) # calculate the variance and its sqrt()
sigma2 = np.var(post) # calculate the variance and its sqrt()
sigma = np.sqrt(((sigma1)+(sigma2))/2)

mean_pre = abs(np.mean(pre))
mean_post = abs(np.mean(post))

T = (mean_pre - mean_post) / (sigma * np.sqrt(2/n))

xs = np.linspace(-5, +5, 1000)
ts = stats.t.pdf(xs, n - 1)
plt.plot(xs, ts, color="lightseagreen")
plt.fill_between(xs, ts, where=np.abs(xs) > np.abs(T), color='darkorchid')
plt.axvline(T, linestyle='--', color='steelblue')
plt.axvline(-T, linestyle='--', color='steelblue')
plt.ylabel("a.u.")
plt.xlabel("t")
plt.show()

# now we calculate the p-value.
pvalue = stats.t.cdf(T, n - 1) + (1. - stats.t.cdf(-T, n - 1))
print("p-value =", pvalue)

#there are no significant changes between pre and post
# Out:
# p-value = 0.0031489409354536393

# %% [markdown]
# 3\. **Curve fitting of temperature in Alaska**
#
# The temperature extremes in Alaska for each month, starting in January, are given by (in degrees Celcius):
#
# max:  `17,  19,  21,  28,  33,  38, 37,  37,  31,  23,  19,  18`
#
# min: `-62, -59, -56, -46, -32, -18, -9, -13, -25, -46, -52, -58`
#
# * Plot these temperatures.
# * Find a suitable a function that can describe min and max temperatures.
# * Fit this function to the data with `scipy.optimize.curve_fit()`.
# * Plot the result. Is the fit reasonable? If not, why?
# * Is the time offset for min and max temperatures the same within the fit accuracy?

# %%
temp_max = np.array([17,  19,  21,  28,  33,  38, 37,  37,  31,  23,  19,  18])
temp_min = np.array([-62, -59, -56, -46, -32, -18, -9, -13, -25, -46, -52, -58])

#Plot these temperatures.
months = np.arange(12)
days = np.linspace(0, 12, num=365)

plt.figure(figsize= (10,8))
plt.plot(months, temp_max, 'o',color='lightcoral')
plt.plot(months, temp_min, 'o', color ='lightskyblue')
#plt.legend('max temperature', 'min temperature', loc="best")
plt.xlabel('Months')
plt.ylabel('Temperature')
 
#Find a suitable a function that can describe min and max temperatures. 
def temps_max(x, A, mean, sigma):
    return A * np.exp(-(x - mean) ** 2 / (2 * sigma ** 2))

#i was thinkin about using a gaussian distribution as a function, but it works only for the maximum temperatures
(mean_max,sigma_max) = norm.fit(temp_max)
(mean_min,sigma_min) = norm.fit(temp_min)

#Fit this function to the data with scipy.optimize.curve_fit()
par_max, cov_max = optimize.curve_fit(temps_max, months, temp_max, p0=(1,mean_max,sigma_max))
#par_min, cov_min = optimize.curve_fit(temps_min,months, temp_min, p0=(1,mean_min,sigma_min))


#plot the results
plt.figure()
plt.plot(months, temp_max, 'o',color='lightcoral')
plt.plot(days, temps_max(days, *par_max), 'r-')
plt.plot(months, temp_min, 'o', color ='lightskyblue')
#plt.plot(days, temps_min(days, *par_min), 'b-')
plt.xlabel('Month')
plt.ylabel('Temperature')
plt.show()

#*  Is the fit reasonable? If not, why?
#* Is the time offset for min and max temperatures the same within the fit accuracy?
# Yes it is a reasonable fit.

# %% [markdown]
# 4\. **Fit the residues**
#
# Read the `data/residuals_261.pkl` file. If you haven't got it already, download it from here:
#
# ```bash
# wget https://www.dropbox.com/s/3uqleyc3wyz52tr/residuals_261.pkl -P data/
# ```
#
# The feature named `residual` contains the residuals (defined as $y_i - \hat{y}_i$) of a linear regression as a function of the independent variable `distances`.
#
# - Considering only the "residual" feature, create an histogram with the appropriate binning and plot it.
# - Set the appropriate Poisson uncertainty for each bin (thus, for each bin, $\sigma_i = \sqrt{n_i}$, where $n_i$ is the number of entries in each bin)
# - By looking at the distribution of the residuals, define an appropriate function and fit it to the histogram of the residuals
# - Perform a goodness-of-fit test. Is the p-value of the fit satisfactory?

# %%
#load the data into dataframe and conver it to pandas dataframe
data=np.load("./data/residuals_261.pkl",allow_pickle=True).item()
data=pd.DataFrame(data,columns=['residuals'])

#histogram plot
(n, bins, patches) = plt.hist(data,bins='auto',align='mid',range=(-8,1), color="powderblue")
x = np.linspace(bins[0], bins[len(n)-1],len(n))

#Poisson uncertainty
sigma = (np.sqrt(n[i]) for i in range(len(n)))

#function fitting to the histogram
#from the histogram it is possible to see that a gaussian function is the best fit
def f(x, A, mean, sigma):
    return A * np.exp(-(x - mean) ** 2 / (2 * sigma ** 2))

(mu, sigma) = norm.fit(data)
par, cov = optimize.curve_fit(f,x, bins, p0=(1,mu,sigma))

plt.plot(x, data(x,*par), 'r-')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [66], line 18
#      15     return A * np.exp(-(x - mean) ** 2 / (2 * sigma ** 2))
#      17 (mu, sigma) = norm.fit(data)
# ---> 18 par, cov = optimize.curve_fit(f,x, bins, p0=(1,mu,sigma))
#      20 plt.plot(x, data(x,*par), 'r-')
#      22 plt.show()
#
# File c:\Python\lib\site-packages\scipy\optimize\_minpack_py.py:834, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, **kwargs)
#     831 if ydata.size != 1 and n > ydata.size:
#     832     raise TypeError(f"The number of func parameters={n} must not"
#     833                     f" exceed the number of data points={ydata.size}")
# --> 834 res = leastsq(func, p0, Dfun=jac, full_output=1, **kwargs)
#     835 popt, pcov, infodict, errmsg, ier = res
#     836 ysize = len(infodict['fvec'])
#
# File c:\Python\lib\site-packages\scipy\optimize\_minpack_py.py:410, in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     408 if not isinstance(args, tuple):
#     409     args = (args,)
# --> 410 shape, dtype = _check_func('leastsq', 'func', func, x0, args, n)
#     411 m = shape[0]
#     413 if n > m:
#
# File c:\Python\lib\site-packages\scipy\optimize\_minpack_py.py:24, in _check_func(checker, argname, thefunc, x0, args, numinputs, output_shape)
#      22 def _check_func(checker, argname, thefunc, x0, args, numinputs,
#      23                 output_shape=None):
# ---> 24     res = atleast_1d(thefunc(*((x0[:numinputs],) + args)))
#      25     if (output_shape is not None) and (shape(res) != output_shape):
#      26         if (output_shape[0] != 1):
#
# File c:\Python\lib\site-packages\scipy\optimize\_minpack_py.py:485, in _wrap_func.<locals>.func_wrapped(params)
#     484 def func_wrapped(params):
# --> 485     return func(xdata, *params) - ydata
#
# ValueError: operands could not be broadcast together with shapes (264,) (265,)

# %% [markdown]
# 5\. **Temperatures in Munich**
#
# Get the following data file:
#
# ```bash
# https://www.dropbox.com/s/7gy9yjl00ymxb8h/munich_temperatures_average_with_bad_data.txt
# ```
#
# which gives the temperature in Munich every day for several years.
#
#
# Fit the following function to the data:
#
# $$f(t) = a \cos(2\pi t + b)+c$$
#
# where $t$ is the time in years.
#
# - Make a plot of the data and the best-fit model in the range 2008 to 2012.
#
#    - What are the best-fit values of the parameters?
#
#    - What is the overall average temperature in Munich, and what are the typical daily average values predicted by the model for the coldest and hottest time of year?
#
#    - What is the meaning of the $b$ parameter, and what physical sense does it have?
#
#
# - Now fit the data with the function $g(x)$, which has 1 more parameter than $f(x)$.
# $$g(x) = a \cos(2\pi b t + c)+d$$
#    - What are the RSS for $f(x)$ and $g(x)$?
#    - Use the Fisher F-test to determine whether the additional parameter is motivated.
